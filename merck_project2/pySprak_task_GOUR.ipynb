# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2653952990305056#setting/sparkui/0912-162646-d6715bxo/driver-7031532703284656021">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
print(spark)

# %%
pivoted_df = spark.read.csv("dbfs:/FileStore/tables/Pyspark_Task.csv", header = True, inferSchema = True)

# %%
pivoted_df.show()
# Out:
# +-------+----------+--------+--------+--------+--------+--------+------+------+------+------+------+
# |Product|Plant Name|Sales_18|Sales_19|Sales_20|Sales_21|Sales_22|Inv_18|Inv_19|Inv_20|Inv_21|Inv_22|
# +-------+----------+--------+--------+--------+--------+--------+------+------+------+------+------+
# |     P1|       PL1|   20000|   25000|   19000|   22000|   23000| 13000| 12000| 13000| 13500| 14000|
# |     P2|       PL1|   80000|   90000|   75000|   78000|  100000| 18000| 18000| 18000| 18000| 18000|
# |     P3|       PL3|   35000|   32000|   56000|   40000|   42000| 17000| 20000| 16000| 15000| 15000|
# |     P4|       PL2|   15000|   23000|   42000|   12000|   13000| 13000| 13000| 13000| 13000| 13000|
# |     P5|       PL1|   85000|   19000|   24000|   15000|   13000| 20000| 22000| 23000| 23000| 21000|
# +-------+----------+--------+--------+--------+--------+--------+------+------+------+------+------+

# %%
from pyspark.sql.functions import *

# %%
Unpivot_data = "stack(10, 'Sales_18', Sales_18, 'Sales_19', Sales_19, 'Sales_20', Sales_20, 'Sales_21', Sales_21, 'Sales_22', Sales_22, 'Inv_18', Inv_18, 'Inv_19', Inv_19, 'Inv_20', Inv_20, 'Inv_21', Inv_21, 'Inv_22', Inv_22) as (Metric,Value)"

# %%
df1 = pivoted_df.select("Product", "Plant Name",expr(Unpivot_data))
df1.show(51)
# Out:
# +-------+----------+--------+------+
# |Product|Plant Name|  Metric| Value|
# +-------+----------+--------+------+
# |     P1|       PL1|Sales_18| 20000|
# |     P1|       PL1|Sales_19| 25000|
# |     P1|       PL1|Sales_20| 19000|
# |     P1|       PL1|Sales_21| 22000|
# |     P1|       PL1|Sales_22| 23000|
# |     P1|       PL1|  Inv_18| 13000|
# |     P1|       PL1|  Inv_19| 12000|
# |     P1|       PL1|  Inv_20| 13000|
# |     P1|       PL1|  Inv_21| 13500|
# |     P1|       PL1|  Inv_22| 14000|
# |     P2|       PL1|Sales_18| 80000|
# |     P2|       PL1|Sales_19| 90000|
# |     P2|       PL1|Sales_20| 75000|
# |     P2|       PL1|Sales_21| 78000|
# |     P2|       PL1|Sales_22|100000|
# |     P2|       PL1|  Inv_18| 18000|
# |     P2|       PL1|  Inv_19| 18000|
# |     P2|       PL1|  Inv_20| 18000|
# |     P2|       PL1|  Inv_21| 18000|
# |     P2|       PL1|  Inv_22| 18000|
# |     P3|       PL3|Sales_18| 35000|
# |     P3|       PL3|Sales_19| 32000|
# ...
